# %% [markdown]
# # Data Analysis of world top companies

# %% [markdown]
# ## 1. Importing necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np")

# %% [markdown]
# ## 2. Loading the Dataset

# %%
# Load the dataset
file_path = r'C:\Users\Blue Star Computer\OneDrive\Desktop\DEP internship Task 3\world_top_companies.xlsx'
df = pd.read_excel(file_path)

# %% [markdown]
# ## 3. Data Overview

# %%
# Display basic information about the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                50 non-null     int64
#  1   Company Name        50 non-null     object
#  2   Industry            50 non-null     object
#  3   Revenue             50 non-null     int64
#  4   Profit              50 non-null     int64
#  5   Employees           50 non-null     int64
#  6   Headquarters        50 non-null     object
#  7   Revenue per worker  50 non-null     float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 3.3+ KB

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Rank                  0
# Company Name          0
# Industry              0
# Revenue               0
# Profit                0
# Employees             0
# Headquarters          0
# Revenue per worker    0
# dtype: int64

# %% [markdown]
# ## 4. Data Cleaning

# %%
# Drop any rows with missing values
df_cleaned = df.dropna()

# Remove duplicates
df_cleaned = df_cleaned.drop_duplicates()

# Display the cleaned dataframe
df_cleaned.head()
# Out:
#    Rank                     Company Name     Industry  Revenue  Profit  \
# 0     1                          Walmart       Retail   611289   11680
# 1     2                     Saudi Aramco  Oil and gas   603651  159069
# 2     3                           Amazon       Retail   574785   30425
# 3     4  State Grid Corporation of China  Electricity   530009    8192
# 4     5                            Vitol  Commodities   505000   15000
#
#    Employees   Headquarters  Revenue per worker
# 0    2100000  United States        2.910900e+05
# 1      70496   Saudi Arabia        8.562911e+06
# 2    1525000  United States        3.769080e+05
# 3     870287          China        6.090048e+05
# 4       1560    Switzerland        3.237179e+08

# %% [markdown]
# ## 5. Exploratory Data Analysis (EDA)

# %%
# Summary statistics
df_cleaned.describe()
# Out:
#            Rank        Revenue         Profit     Employees  \
# count  50.00000      50.000000      50.000000  5.000000e+01
# mean   25.50000  275541.280000   22791.500000  3.197594e+05
# std    14.57738  127423.768594   28128.685785  3.930362e+05
# min     1.00000  157403.000000    1699.000000  1.560000e+03
# 25%    13.25000  176779.500000    6749.500000  7.029725e+04
# 50%    25.50000  236358.000000   15116.500000  2.208800e+05
# 75%    37.75000  315328.250000   20941.500000  3.828730e+05
# max    50.00000  611289.000000  159069.000000  2.100000e+06
#
#        Revenue per worker
# count        5.000000e+01
# mean         1.022042e+07
# std          4.581149e+07
# min          2.779130e+05
# 25%          5.612570e+05
# 50%          9.053868e+05
# 75%          3.875228e+06
# max          3.237179e+08

# %% [markdown]
# ### 6. Plotting the distribution of companies by industry

# %%
plt.figure(figsize=(12, 6))
sns.countplot(y='Industry', data=df_cleaned, order=df_cleaned['Industry'].value_counts().index)
plt.title('Distribution of Companies by Industry')
plt.xlabel('Number of Companies')
plt.ylabel('Industry')
plt.show()

# %% [markdown]
# ### Plotting the distribution of profits across industries

# %%
plt.figure(figsize=(12, 6))
sns.countplot(y='Industry', data=df_cleaned, order=df_cleaned['Industry'].value_counts().index)
plt.title(' Profit Distribution across Industries')
plt.xlabel('Profit (in millions)')
plt.ylabel('Industry')
plt.show()

# %% [markdown]
# ### Plotting the top 10 companies by revenue

# %%
# Extracting the top 10 companies by profit
profit_by_company = df.nlargest(10, 'Revenue')

# Plotting Company Name vs Profit
plt.figure(figsize=(14, 8))
sns.barplot(x='Revenue', y='Company Name', data=top_companies_revenue, hue='Company Name', palette="viridis", dodge=False, legend=False)
plt.title('Top Companies by revenue',fontsize=16, weight='bold')
plt.xlabel('Revenue (in Millions)', fontsize=14)
plt.ylabel('Company Name',fontsize=14)
plt.show()

# %% [markdown]
# ### Plotting the top 10 companies by profit

# %%
# Extracting the top 10 companies by profit
profit_by_company = df.nlargest(10, 'Profit')

# Plotting Company Name vs Profit
plt.figure(figsize=(14, 8))
sns.barplot(x='Profit', y='Company Name', data=top_companies_revenue, hue='Company Name', palette="viridis", dodge=False, legend=False)
plt.title('Top Companies by Profit',fontsize=16, weight='bold')
plt.xlabel('Profit (in Millions)', fontsize=14)
plt.ylabel('Company Name',fontsize=14)
plt.show()

# %% [markdown]
# ### plotting the top 10 companies by employees

# %%
# Extracting the top 10 companies by employees
Number_of_Employees_by_Company = df_cleaned.nlargest(10, 'Employees')

# Plotting Company Name vs Employees
plt.figure(figsize=(14, 8))
sns.barplot(x='Employees', y='Company Name', data=Number_of_Employees_by_Company, hue='Company Name', palette="viridis", dodge=False, legend=False)
plt.title('Number of Employees by Company', fontsize=16, weight='bold')
plt.xlabel('Number of Employees (in Millions)', fontsize=14)
plt.ylabel('Company Name', fontsize=16)
plt.show()
